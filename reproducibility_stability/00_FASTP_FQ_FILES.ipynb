# %%
#download samples: /BSSE_TREUTLEIN/TREUTLEIN/P2794_HSIU-CHUAN/POOL-631

# %%
python /links/groups/treutlein/SCRIPTS/sequencing/get_sequencing_results.py -h
# Out:
# Traceback (most recent call last):
#   File "/links/groups/treutlein/SCRIPTS/sequencing/get_sequencing_results.py", line 6, in <module>
#     import git
# ModuleNotFoundError: No module named 'git'
# : 1

# %%
python /links/groups/treutlein/SCRIPTS/sequencing/get_sequencing_results.py /BSSE_TREUTLEIN/POOL-631

# %%
mamba activate bulk_seq
# Out:
# (bulk_seq)
# : 1

# %%
which fastp
# Out:
# /nas/groups/treutlein/USERS/jjans/mambaforge/envs/bulk_seq/bin/fastp
# (bulk_seq)
# : 1

# %%
which STAR
# Out:
# /nas/groups/treutlein/USERS/jjans/mambaforge/envs/bulk_seq/bin/STAR
# (bulk_seq)
# : 1

# %%
ls /links/groups/treutlein/DATA/sequencing/20240524_P2794_HSIU-CHUAN/raw/*/*R1*.fastq.gz
# Out:
# /links/groups/treutlein/DATA/sequencing/20240524_P2794_HSIU-CHUAN/raw/Reproducibility_409B2_1_1/Reproducibility_409B2_1_1_S1_L001_R1_001.fastq.gz
# /links/groups/treutlein/DATA/sequencing/20240524_P2794_HSIU-CHUAN/raw/Reproducibility_409B2_1_1/Reproducibility_409B2_1_1_S2_L002_R1_001.fastq.gz
# /links/groups/treutlein/DATA/sequencing/20240524_P2794_HSIU-CHUAN/raw/Reproducibility_409B2_1_10/Reproducibility_409B2_1_10_S1_L001_R1_001.fastq.gz
# /links/groups/treutlein/DATA/sequencing/20240524_P2794_HSIU-CHUAN/raw/Reproducibility_409B2_1_10/Reproducibility_409B2_1_10_S2_L002_R1_001.fastq.gz
# /links/groups/treutlein/DATA/sequencing/20240524_P2794_HSIU-CHUAN/raw/Reproducibility_409B2_1_11/Reproducibility_409B2_1_11_S1_L001_R1_001.fastq.gz
# /links/groups/treutlein/DATA/sequencing/20240524_P2794_HSIU-CHUAN/raw/Reproducibility_409B2_1_11/Reproducibility_409B2_1_11_S2_L002_R1_001.fastq.gz
# ...

# %%
export MAXCORES=8
export STARGEN=/local1/sequencing/PUBLIC_DATA/genomes/refdata-cellranger-arc-GRCh38-2020-A-2.0.0/star/
ls /links/groups/treutlein/DATA/sequencing/20240524_P2794_HSIU-CHUAN/raw/*/*R1*.fastq.gz | parallel -j 15 --plus --rpl '{/..L} s:.fastq.gz::;s:.*/::;s:_R.*::' --rpl '{/..} s:.fastq.gz::;s:.*/::;s:_S.*::' "
        mkdir -p {/..}
        cd {/..}
        
        mkdir -p 00.CLEAN_FQ
        fastp -i {} -I {=s/R1/R2/=} -o 00.CLEAN_FQ/{/..L}_R1.clean.fastq.gz -O 00.CLEAN_FQ/{/..L}_R2.clean.fastq.gz -h 00.CLEAN_FQ/{/..L}_fastp.html -j 00.CLEAN_FQ/{/..L}_fastp.json &>> {/..L}_fastp.log
        
        cat 00.CLEAN_FQ/*_R1.clean.fastq.gz > 00.CLEAN_FQ/{/..}_R1.merged.fastq.gz
        cat 00.CLEAN_FQ/*_R2.clean.fastq.gz > 00.CLEAN_FQ/{/..}_R2.merged.fastq.gz
       
"
# Out:
# (bulk_seq)
# (bulk_seq)
# Academic tradition requires you to cite works you base your article on.
# If you use programs that use GNU Parallel to process data for an article in a
# scientific publication, please cite:
#
#   Tange, O. (2024, May 22). GNU Parallel 20240522 ('Tbilisi').
#   Zenodo. https://doi.org/10.5281/zenodo.11247979
#
# This helps funding further development; AND IT WON'T COST YOU A CENT.
# If you pay 10000 EUR you should feel free to use GNU Parallel without citing.
#
# More about funding GNU Parallel and the citation notice:
# https://www.gnu.org/software/parallel/parallel_design.html#citation-notice
#
# To silence this citation notice: run 'parallel --citation' once.
#
# Come on: You have run parallel 26 times. Isn't it about time
# you run 'parallel --citation' once to silence the citation notice?
#
# /nas/groups/treutlein/USERS/jjans/analysis/iNeuron_morphogens/revisions/bulk_experiments/Reproducibility_409B2_1_10
# ...

# %%
ls Reproducibility_SC102A1/00.CLEAN_FQ
# Out:
# Reproducibility_R1.merged.fastq.gz
# Reproducibility_R2.merged.fastq.gz
# Reproducibility_SC102A1_1_10_S1_L001_R1.clean.fastq.gz
# Reproducibility_SC102A1_1_10_S1_L001_R2.clean.fastq.gz
# Reproducibility_SC102A1_1_10_S1_L001_fastp.html
# Reproducibility_SC102A1_1_10_S1_L001_fastp.json
# Reproducibility_SC102A1_1_10_S2_L002_R1.clean.fastq.gz
# Reproducibility_SC102A1_1_10_S2_L002_R2.clean.fastq.gz
# Reproducibility_SC102A1_1_10_S2_L002_fastp.html
# Reproducibility_SC102A1_1_10_S2_L002_fastp.json
# Reproducibility_SC102A1_1_11_S1_L001_R1.clean.fastq.gz
# Reproducibility_SC102A1_1_11_S1_L001_R2.clean.fastq.gz
# Reproducibility_SC102A1_1_11_S1_L001_fastp.html
# Reproducibility_SC102A1_1_11_S1_L001_fastp.json
# Reproducibility_SC102A1_1_11_S2_L002_R1.clean.fastq.gz
# Reproducibility_SC102A1_1_11_S2_L002_R2.clean.fastq.gz
# Reproducibility_SC102A1_1_11_S2_L002_fastp.html
# Reproducibility_SC102A1_1_11_S2_L002_fastp.json
# Reproducibility_SC102A1_1_12_S1_L001_R1.clean.fastq.gz
# ...

# %%
# Base directory containing the files
BASE_DIR="Reproducibility_SC102A1/00.CLEAN_FQ"

# Loop through each file
for FILE in $BASE_DIR/*.fastq.gz; do
    # Extract base name without the lane and read-specific parts
    BASE_NAME=$(echo $(basename $FILE) | sed 's/_S[0-9]\+_L[0-9]\+_R[12]\.clean\.fastq\.gz//')
    
    # Create target directory if it doesn't exist
    TARGET_DIR="Reproducibility_SC102A1/$BASE_NAME/00.CLEAN_FQ"
    mkdir -p $TARGET_DIR
    
    # Move the file to the target directory
    mv $FILE $TARGET_DIR/
done
# Out:
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# : 1

# %%
# Base directory containing the files
BASE_DIR="Reproducibility_SC102A1/00.CLEAN_FQ"

# Loop through each file
for FILE in $BASE_DIR/*.html; do
    # Extract base name without the lane and read-specific parts
    BASE_NAME=$(echo $(basename $FILE) | sed 's/_S[0-9]\+_L[0-9]\+_R[12]\.html//')
    
    # Create target directory if it doesn't exist
    TARGET_DIR="Reproducibility_SC102A1/$BASE_NAME/00.CLEAN_FQ"
    mkdir -p $TARGET_DIR
    
    # Move the file to the target directory
    mv $FILE $TARGET_DIR/
done
# Out:
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# : 1

# %%
# Base directory containing the files
BASE_DIR="Reproducibility_SC102A1/00.CLEAN_FQ"

# Loop through each file
for FILE in $BASE_DIR/*.json; do
    # Extract base name without the lane and read-specific parts
    BASE_NAME=$(echo $(basename $FILE) | sed 's/_S[0-9]\+_L[0-9]\+_R[12]\.json//' | sed 's/_S[1|2].*//')
    
    echo $BASE_NAME
    # Create target directory if it doesn't exist
    TARGET_DIR="Reproducibility_SC102A1/$BASE_NAME/00.CLEAN_FQ"
    mkdir -p $TARGET_DIR
    
    # Move the file to the target directory
    mv $FILE $TARGET_DIR/

done
# Out:
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# Reproducibility_SC102A1_1_10
# Reproducibility_SC102A1_1_10
# Reproducibility_SC102A1_1_11
# Reproducibility_SC102A1_1_11
# Reproducibility_SC102A1_1_12
# Reproducibility_SC102A1_1_12
# Reproducibility_SC102A1_1_1
# Reproducibility_SC102A1_1_1
# Reproducibility_SC102A1_1_2
# Reproducibility_SC102A1_1_2
# Reproducibility_SC102A1_1_3
# Reproducibility_SC102A1_1_3
# Reproducibility_SC102A1_1_4
# Reproducibility_SC102A1_1_4
# Reproducibility_SC102A1_1_5
# Reproducibility_SC102A1_1_5
# Reproducibility_SC102A1_1_6
# Reproducibility_SC102A1_1_6
# Reproducibility_SC102A1_1_7
# Reproducibility_SC102A1_1_7
# Reproducibility_SC102A1_1_8
# Reproducibility_SC102A1_1_8
# Reproducibility_SC102A1_1_9
# Reproducibility_SC102A1_1_9
# Reproducibility_SC102A1_2_10
# Reproducibility_SC102A1_2_10
# Reproducibility_SC102A1_2_11
# Reproducibility_SC102A1_2_11
# Reproducibility_SC102A1_2_12
# Reproducibility_SC102A1_2_12
# ...

# %%
# Base directory containing the files
BASE_DIR="Reproducibility_SC102A1/00.CLEAN_FQ"

# Loop through each file
for FILE in $BASE_DIR/*.html; do
    # Extract base name without the lane and read-specific parts
    BASE_NAME=$(echo $(basename $FILE) | sed 's/_S[0-9]\+_L[0-9]\+_R[12]\.html//' | sed 's/_S[1|2].*//')
    
    echo $BASE_NAME
    # Create target directory if it doesn't exist
    TARGET_DIR="Reproducibility_SC102A1/$BASE_NAME/00.CLEAN_FQ"
    mkdir -p $TARGET_DIR
    
    # Move the file to the target directory
    mv $FILE $TARGET_DIR/

done
# Out:
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# Reproducibility_SC102A1_1_10
# Reproducibility_SC102A1_1_10
# Reproducibility_SC102A1_1_11
# Reproducibility_SC102A1_1_11
# Reproducibility_SC102A1_1_12
# Reproducibility_SC102A1_1_12
# Reproducibility_SC102A1_1_1
# Reproducibility_SC102A1_1_1
# Reproducibility_SC102A1_1_2
# Reproducibility_SC102A1_1_2
# Reproducibility_SC102A1_1_3
# Reproducibility_SC102A1_1_3
# Reproducibility_SC102A1_1_4
# Reproducibility_SC102A1_1_4
# Reproducibility_SC102A1_1_5
# Reproducibility_SC102A1_1_5
# Reproducibility_SC102A1_1_6
# Reproducibility_SC102A1_1_6
# Reproducibility_SC102A1_1_7
# Reproducibility_SC102A1_1_7
# Reproducibility_SC102A1_1_8
# Reproducibility_SC102A1_1_8
# Reproducibility_SC102A1_1_9
# Reproducibility_SC102A1_1_9
# Reproducibility_SC102A1_2_10
# Reproducibility_SC102A1_2_10
# Reproducibility_SC102A1_2_11
# Reproducibility_SC102A1_2_11
# Reproducibility_SC102A1_2_12
# Reproducibility_SC102A1_2_12
# ...

# %%
rmdir Reproducibility_SC102A1/00.CLEAN_FQ
# Out:
# (bulk_seq)
# : 1

# %%
# Define the base directory
BASE_DIR="Reproducibility_SC102A1"

# Move .log files to their corresponding folders
for LOG_FILE in $BASE_DIR/*.log; do
    # Extract the prefix of the filename
    PREFIX=$(basename "$LOG_FILE" | cut -d'_' -f1-4)
    
    # Define the target directory
    TARGET_DIR="$BASE_DIR/$PREFIX"
    
    echo $TARGET_DIR
    echo $LOG_FILE
    # Move the .log file to the target directory
    mv "$LOG_FILE" "$TARGET_DIR/"

done
# Out:
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_10
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_10_S1_L001_fastp.log
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_10
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_10_S2_L002_fastp.log
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_11
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_11_S1_L001_fastp.log
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_11
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_11_S2_L002_fastp.log
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_12
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_12_S1_L001_fastp.log
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_12
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_12_S2_L002_fastp.log
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_1
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_1_S1_L001_fastp.log
# Reproducibility_SC102A1/Reproducibility_SC102A1_1_1
# ...

# %%
ls Reproducibility_SC102A1/Reproducibility_SC102A1_1_1/00.CLEAN_FQ
# Out:
# Reproducibility_SC102A1_1_1_S1_L001_R1.clean.fastq.gz
# Reproducibility_SC102A1_1_1_S1_L001_R2.clean.fastq.gz
# Reproducibility_SC102A1_1_1_S1_L001_fastp.html
# Reproducibility_SC102A1_1_1_S1_L001_fastp.json
# Reproducibility_SC102A1_1_1_S2_L002_R1.clean.fastq.gz
# Reproducibility_SC102A1_1_1_S2_L002_R2.clean.fastq.gz
# Reproducibility_SC102A1_1_1_S2_L002_fastp.html
# Reproducibility_SC102A1_1_1_S2_L002_fastp.json
# (bulk_seq)
# : 1

# %%
# Define the base directory
BASE_DIR="Reproducibility_SC102A1"

# Merge FASTQ files within each folder
for FOLDER in $BASE_DIR/*; do
    # Skip if not a directory
    if [ ! -d "$FOLDER" ]; then
        continue
    fi
    
    # Get the folder name
    FOLDER_NAME=$(basename "$FOLDER")
    
    # Merge FASTQ files within the folder
    cd "$FOLDER"/00.CLEAN_FQ
    cat *_R1.clean.fastq.gz > "$FOLDER_NAME"_R1.merged.fastq.gz
    cat *_R2.clean.fastq.gz > "$FOLDER_NAME"_R2.merged.fastq.gz
    cd ../../..
done
# Out:
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# /nas/groups/treutlein/USERS/jjans/analysis/iNeuron_morphogens/revisions/bulk_experiments/Reproducibility_SC102A1/Reproducibility_SC102A1_1_1/00.CLEAN_FQ
# /nas/groups/treutlein/USERS/jjans/analysis/iNeuron_morphogens/revisions/bulk_experiments/Reproducibility_SC102A1/Reproducibility_SC102A1_1_10/00.CLEAN_FQ
# /nas/groups/treutlein/USERS/jjans/analysis/iNeuron_morphogens/revisions/bulk_experiments/Reproducibility_SC102A1/Reproducibility_SC102A1_1_11/00.CLEAN_FQ
# /nas/groups/treutlein/USERS/jjans/analysis/iNeuron_morphogens/revisions/bulk_experiments/Reproducibility_SC102A1/Reproducibility_SC102A1_1_12/00.CLEAN_FQ
# /nas/groups/treutlein/USERS/jjans/analysis/iNeuron_morphogens/revisions/bulk_experiments/Reproducibility_SC102A1/Reproducibility_SC102A1_1_2/00.CLEAN_FQ
# /nas/groups/treutlein/USERS/jjans/analysis/iNeuron_morphogens/revisions/bulk_experiments/Reproducibility_SC102A1/Reproducibility_SC102A1_1_3/00.CLEAN_FQ
# ...

# %%
cd ..
# Out:
# (bulk_seq)
# : 1

# %%
cd ..
# Out:
# (bulk_seq)
# : 1

# %%
# Define the base directory
BASE_DIR="Reproducibility_SC102A1"

# Move .log files to their corresponding folders
for LOG_FILE in $BASE_DIR/*.log; do
    # Extract the prefix of the filename
    PREFIX=$(basename "$LOG_FILE" | cut -d'_' -f1-3)
    
    # Define the target directory
    TARGET_DIR="$BASE_DIR/$PREFIX"
    
    # Move the .log file to the target directory
    mv "$LOG_FILE" "$TARGET_DIR/"
done

# %%
ls
# Out:
# Reproducibility_SC102A1_1_1
# Reproducibility_SC102A1_1_10
# Reproducibility_SC102A1_1_10_S1_L001_fastp.log
# Reproducibility_SC102A1_1_10_S2_L002_fastp.log
# Reproducibility_SC102A1_1_11
# Reproducibility_SC102A1_1_11_S1_L001_fastp.log
# Reproducibility_SC102A1_1_11_S2_L002_fastp.log
# Reproducibility_SC102A1_1_12
# Reproducibility_SC102A1_1_12_S1_L001_fastp.log
# Reproducibility_SC102A1_1_12_S2_L002_fastp.log
# Reproducibility_SC102A1_1_1_S1_L001_fastp.log
# Reproducibility_SC102A1_1_1_S2_L002_fastp.log
# Reproducibility_SC102A1_1_2
# Reproducibility_SC102A1_1_2_S1_L001_fastp.log
# Reproducibility_SC102A1_1_2_S2_L002_fastp.log
# Reproducibility_SC102A1_1_3
# Reproducibility_SC102A1_1_3_S1_L002_fastp.log
# Reproducibility_SC102A1_1_3_S2_L001_fastp.log
# Reproducibility_SC102A1_1_4
# Reproducibility_SC102A1_1_4_S1_L002_fastp.log
# Reproducibility_SC102A1_1_4_S2_L001_fastp.log
# Reproducibility_SC102A1_1_5
# Reproducibility_SC102A1_1_5_S1_L002_fastp.log
# ...

# %%
cd ..
# Out:
# (bulk_seq)
# : 1

# %%
# Base directory containing the files
BASE_DIR="Reproducibility_SC102A1/00.CLEAN_FQ"

# Loop through each file
for FILE in $BASE_DIR/*.json; do
    # Extract base name without the lane and read-specific parts
    BASE_NAME=$(echo $(basename $FILE) | sed 's/_S[0-9]\+_L[0-9]\+_R[12]\.json//')
    
    # Create target directory if it doesn't exist
    TARGET_DIR="Reproducibility_SC102A1/$BASE_NAME/00.CLEAN_FQ"
    mkdir -p $TARGET_DIR
    
    # Move the file to the target directory
    mv $FILE $TARGET_DIR/
done
# Out:
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# (bulk_seq)
# : 1

# %%
cd Reproducibility_SC102A1
# Out:
# /nas/groups/treutlein/USERS/jjans/analysis/iNeuron_morphogens/revisions/bulk_experiments/Reproducibility_SC102A1
# (bulk_seq)
# : 1

# %%
mv */*/*.html 00.CLEAN_FQ/
# Out:
# (bulk_seq)
# : 1

# %%
rm -r Reproducibility_SC102A1_1_1_S1_L001_fastp.html
# Out:
# (bulk_seq)
# : 1

# %%
rmdir *.json
# Out:
# (bulk_seq)
# : 1

# %%
rm -r Reproducibility_SC102A1/Reproducibility_R2.merged.fastq.gz
# Out:
# (bulk_seq)
# : 1

# %%
ls Reproducibility_SC102A1/00.CLEAN_FQ/*.fastq.gz
# Out:
# Reproducibility_SC102A1/00.CLEAN_FQ/Reproducibility_R1.merged.fastq.gz
# Reproducibility_SC102A1/00.CLEAN_FQ/Reproducibility_R2.merged.fastq.gz
# Reproducibility_SC102A1/00.CLEAN_FQ/Reproducibility_SC102A1_1_10_S1_L001_R1.clean.fastq.gz
# Reproducibility_SC102A1/00.CLEAN_FQ/Reproducibility_SC102A1_1_10_S1_L001_R2.clean.fastq.gz
# Reproducibility_SC102A1/00.CLEAN_FQ/Reproducibility_SC102A1_1_10_S2_L002_R1.clean.fastq.gz
# Reproducibility_SC102A1/00.CLEAN_FQ/Reproducibility_SC102A1_1_10_S2_L002_R2.clean.fastq.gz
# Reproducibility_SC102A1/00.CLEAN_FQ/Reproducibility_SC102A1_1_11_S1_L001_R1.clean.fastq.gz
# Reproducibility_SC102A1/00.CLEAN_FQ/Reproducibility_SC102A1_1_11_S1_L001_R2.clean.fastq.gz
# Reproducibility_SC102A1/00.CLEAN_FQ/Reproducibility_SC102A1_1_11_S2_L002_R1.clean.fastq.gz
# Reproducibility_SC102A1/00.CLEAN_FQ/Reproducibility_SC102A1_1_11_S2_L002_R2.clean.fastq.gz
# Reproducibility_SC102A1/00.CLEAN_FQ/Reproducibility_SC102A1_1_12_S1_L001_R1.clean.fastq.gz
# ...
